# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
fold_0 = pd.read_csv("weights/tf_efficientnet_b4_ns_fold0_final.csv")
fold_0
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 0       0    0.459030    0.404657       0.654251       0.742466
# 1       1    0.421261    0.418220       0.705787       0.727030
# 2       2    0.409433    0.394106       0.719255       0.760027
# 3       3    0.406618    0.390566       0.735506       0.756680
# 4       4    0.404446    0.472520       0.738615       0.730960
# 5       5    0.403754    0.395331       0.744638       0.773222
# 6       6    0.381671    0.380147       0.774205       0.783550
# 7       7    0.376395    0.381042       0.784828       0.787159
# 8       8    0.374813    0.374521       0.789569       0.791891
# 9       9    0.368982    0.377442       0.796501       0.795384
# 10     10    0.364884    0.369248       0.803491       0.802205
# 11     11    0.361374    0.375066       0.810389       0.803036
# 12     12    0.358413    0.375870       0.812139       0.800168
# 13     13    0.356614    0.371782       0.815587       0.801696
# ...

# %%
fold_0.loc[[fold_0.roc_auc_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 14     14    0.352192    0.370109       0.823845       0.803044
#
#     average_precision_train  average_precision_valid  fold
# 14                 0.385524                 0.366432     0

# %%
fold_0.loc[[fold_0.average_precision_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 14     14    0.352192    0.370109       0.823845       0.803044
#
#     average_precision_train  average_precision_valid  fold
# 14                 0.385524                 0.366432     0

# %%
fold_0.plot(subplots=True, figsize=(16, 8))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
fold_1 = pd.read_csv("weights/tf_efficientnet_b4_ns_fold1_final.csv")
fold_1
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 0       0    0.456745    0.425971       0.658655       0.733893
# 1       1    0.425591    0.409174       0.694769       0.724692
# 2       2    0.415821    0.389202       0.714516       0.762445
# 3       3    0.409061    0.397949       0.724688       0.750170
# 4       4    0.405182    0.393056       0.737408       0.751149
# 5       5    0.387739    0.374758       0.764450       0.788594
# 6       6    0.380219    0.372591       0.779341       0.791615
# 7       7    0.376213    0.365689       0.786680       0.802032
# 8       8    0.375647    0.366798       0.788462       0.803400
# 9       9    0.367817    0.375285       0.797137       0.802579
# 10     10    0.365046    0.369989       0.803396       0.803062
# 11     11    0.363977    0.366250       0.806596       0.804206
# 12     12    0.362094    0.365113       0.810180       0.804993
# 13     13    0.361490    0.368543       0.812389       0.802196
# ...

# %%
fold_1.loc[[fold_1.roc_auc_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 17     17    0.359473    0.366222       0.813707        0.80535
#
#     average_precision_train  average_precision_valid  fold
# 17                 0.370325                 0.368121     1

# %%
fold_1.loc[[fold_1.average_precision_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 17     17    0.359473    0.366222       0.813707        0.80535
#
#     average_precision_train  average_precision_valid  fold
# 17                 0.370325                 0.368121     1

# %%
fold_1.plot(subplots=True, figsize=(16, 8))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
fold_2 = pd.read_csv("weights/tf_efficientnet_b4_ns_fold2_final.csv")
fold_2
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 0       0    0.448411    0.409748       0.670398       0.745729
# 1       1    0.423439    0.414872       0.706632       0.754071
# 2       2    0.410323    0.387861       0.727048       0.766451
# 3       3    0.410293    0.389190       0.727328       0.783181
# 4       4    0.403469    0.403640       0.739636       0.764660
# 5       5    0.384552    0.380805       0.776149       0.789007
# 6       6    0.377257    0.376399       0.784626       0.789936
# 7       7    0.369285    0.371307       0.797880       0.795829
# 8       8    0.371997    0.370117       0.796653       0.795294
# 9       9    0.366645    0.367703       0.800230       0.803447
# 10     10    0.363627    0.367790       0.806358       0.801261
# 11     11    0.359701    0.369042       0.811500       0.808416
# 12     12    0.355563    0.366734       0.816353       0.808648
# 13     13    0.352202    0.368241       0.822667       0.805921
# ...

# %%
fold_2.loc[[fold_2.roc_auc_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 17     17    0.350071     0.36662       0.826697       0.810149
#
#     average_precision_train  average_precision_valid  fold
# 17                 0.393782                 0.378488     2

# %%
fold_2.loc[[fold_2.average_precision_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 13     13    0.352202    0.368241       0.822667       0.805921
#
#     average_precision_train  average_precision_valid  fold
# 13                 0.388236                 0.379097     2

# %%
fold_2.plot(subplots=True, figsize=(16, 8))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
fold_3 = pd.read_csv("weights/tf_efficientnet_b4_ns_fold3_final.csv")
fold_3
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 0       0    0.455269    0.396350       0.649297       0.739624
# 1       1    0.423038    0.387009       0.700599       0.762543
# 2       2    0.415314    0.384166       0.715033       0.770720
# 3       3    0.413140    0.386963       0.717932       0.777525
# 4       4    0.405820    0.415826       0.733899       0.749001
# 5       5    0.389929    0.366304       0.767312       0.801302
# 6       6    0.379471    0.363597       0.782285       0.808811
# 7       7    0.374810    0.360792       0.787476       0.812741
# 8       8    0.371895    0.355183       0.795084       0.818933
# 9       9    0.366596    0.361242       0.799935       0.817379
# 10     10    0.360894    0.366565       0.806135       0.811220
# 11     11    0.359663    0.359330       0.810948       0.816852
# 12     12    0.360860    0.360911       0.808931       0.813923
# 13     13    0.358647    0.355929       0.811013       0.819466
# ...

# %%
fold_3.loc[[fold_3.roc_auc_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 19     19    0.355926    0.356558         0.8141       0.820037
#
#     average_precision_train  average_precision_valid  fold
# 19                 0.375811                  0.37638     3

# %%
fold_3.loc[[fold_3.average_precision_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 17     17    0.358401    0.356558       0.811489       0.819666
#
#     average_precision_train  average_precision_valid  fold
# 17                 0.377207                 0.376936     3

# %%
fold_3.plot(subplots=True, figsize=(16, 8))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
fold_4 = pd.read_csv("weights/tf_efficientnet_b4_ns_fold4_final.csv")
fold_4
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 0       0    0.452210    0.408918       0.661742       0.723450
# 1       1    0.419282    0.398756       0.708271       0.758631
# 2       2    0.414419    0.390567       0.722321       0.763660
# 3       3    0.409253    0.412016       0.728917       0.753627
# 4       4    0.400173    0.387950       0.746179       0.768520
# 5       5    0.399864    0.393167       0.751173       0.780990
# 6       6    0.392469    0.390803       0.761268       0.776011
# 7       7    0.376507    0.373985       0.786975       0.800001
# 8       8    0.368576    0.372438       0.798897       0.802253
# 9       9    0.366445    0.372140       0.801248       0.805946
# 10     10    0.365247    0.370019       0.803211       0.808731
# 11     11    0.360749    0.376411       0.808000       0.805012
# 12     12    0.357165    0.375314       0.815777       0.805417
# 13     13    0.351580    0.374545       0.824240       0.806732
# ...

# %%
fold_4.loc[[fold_4.roc_auc_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 10     10    0.365247    0.370019       0.803211       0.808731
#
#     average_precision_train  average_precision_valid  fold
# 10                  0.36087                  0.36943     4

# %%
fold_4.loc[[fold_4.average_precision_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 10     10    0.365247    0.370019       0.803211       0.808731
#
#     average_precision_train  average_precision_valid  fold
# 10                  0.36087                  0.36943     4

# %%
fold_4.plot(subplots=True, figsize=(16, 8))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)
