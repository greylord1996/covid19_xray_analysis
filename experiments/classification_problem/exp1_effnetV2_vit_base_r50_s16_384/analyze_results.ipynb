# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
fold_0 = pd.read_csv("weights/vit_base_r50_s16_384_fold0_final.csv")
fold_0
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 0       0    0.449139    0.472810       0.664676       0.744957
# 1       1    0.424055    0.397401       0.702441       0.766925
# 2       2    0.412881    0.455833       0.727500       0.736129
# 3       3    0.406809    0.406858       0.740865       0.773610
# 4       4    0.376077    0.378968       0.787819       0.791440
# 5       5    0.371049    0.376333       0.797052       0.796074
# 6       6    0.368545    0.372361       0.798263       0.798145
# 7       7    0.365121    0.373351       0.808084       0.800446
# 8       8    0.362054    0.370332       0.809167       0.805274
# 9       9    0.358442    0.367552       0.814260       0.808159
# 10     10    0.357344    0.369984       0.816602       0.806432
# 11     11    0.355406    0.368131       0.819974       0.810808
# 12     12    0.347672    0.368174       0.829461       0.810781
# 13     13    0.343759    0.368692       0.834194       0.811452
# 14     14    0.344803    0.368430       0.833284       0.811635
# 15     15    0.343448    0.368392       0.834948       0.811680
# 16     16    0.340585    0.368400       0.837356       0.811689
# 17     17    0.342221    0.368401       0.834866       0.811673
# 18     18    0.345951    0.368382       0.831406       0.811684
# 19     19    0.342942    0.368377       0.834056       0.811681
#
#     average_precision_train  average_precision_valid  fold
# 0                  0.266257                 0.316701     0
# 1                  0.288506                 0.333181     0
# 2                  0.300854                 0.316912     0
# 3                  0.308656                 0.336545     0
# 4                  0.349770                 0.347736     0
# 5                  0.358326                 0.351853     0
# 6                  0.361630                 0.355654     0
# 7                  0.367670                 0.360850     0
# 8                  0.368549                 0.362500     0
# 9                  0.377169                 0.366631     0
# 10                 0.376518                 0.364780     0
# 11                 0.383002                 0.368969     0
# 12                 0.391444                 0.369273     0
# 13                 0.397375                 0.369688     0
# 14                 0.398710                 0.369806     0
# 15                 0.399399                 0.369673     0
# 16                 0.405041                 0.369763     0
# 17                 0.405123                 0.369751     0
# 18                 0.395943                 0.369756     0
# 19                 0.398913                 0.369651     0

# %%
fold_0.loc[[fold_0.roc_auc_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 16     16    0.340585      0.3684       0.837356       0.811689
#
#     average_precision_train  average_precision_valid  fold
# 16                 0.405041                 0.369763     0

# %%
fold_0.loc[[fold_0.average_precision_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 14     14    0.344803     0.36843       0.833284       0.811635
#
#     average_precision_train  average_precision_valid  fold
# 14                  0.39871                 0.369806     0

# %%
fold_0.plot(subplots=True, figsize=(16, 8))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
fold_1 = pd.read_csv("weights/vit_base_r50_s16_384_fold1_final.csv")
fold_1
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 0       0    0.488252    0.433861       0.595690       0.711777
# 1       1    0.430669    0.393840       0.687327       0.766093
# 2       2    0.419544    0.397659       0.716235       0.741911
# 3       3    0.407628    0.397438       0.732248       0.788253
# 4       4    0.383292    0.373149       0.774290       0.796131
# 5       5    0.379063    0.373054       0.781206       0.797375
# 6       6    0.376248    0.372097       0.787450       0.798383
# 7       7    0.371808    0.375114       0.795209       0.800693
# 8       8    0.371015    0.366955       0.797924       0.802583
# 9       9    0.366483    0.374077       0.803491       0.802801
# 10     10    0.364365    0.370830       0.806935       0.803721
# 11     11    0.361027    0.366262       0.813615       0.805343
# 12     12    0.358378    0.365656       0.815243       0.805639
# 13     13    0.356319    0.365860       0.815950       0.805918
# 14     14    0.360228    0.365400       0.811315       0.805277
# 15     15    0.356877    0.366495       0.816152       0.804815
# 16     16    0.358771    0.366410       0.813563       0.805487
# 17     17    0.355717    0.366420       0.817460       0.805576
# 18     18    0.353295    0.366424       0.819946       0.805675
#
#     average_precision_train  average_precision_valid  fold
# 0                  0.221302                 0.301744     1
# 1                  0.280812                 0.336249     1
# 2                  0.293747                 0.325374     1
# 3                  0.305010                 0.353670     1
# 4                  0.334785                 0.359300     1
# 5                  0.343194                 0.361489     1
# 6                  0.346042                 0.366087     1
# 7                  0.351979                 0.365798     1
# 8                  0.355058                 0.368181     1
# 9                  0.359515                 0.370499     1
# 10                 0.367635                 0.369539     1
# 11                 0.376145                 0.371178     1
# 12                 0.374857                 0.371678     1
# 13                 0.381726                 0.372118     1
# 14                 0.373619                 0.372032     1
# 15                 0.377893                 0.371101     1
# 16                 0.374512                 0.371745     1
# 17                 0.380381                 0.371900     1
# 18                 0.379578                 0.371888     1

# %%
fold_1.loc[[fold_1.roc_auc_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 13     13    0.356319     0.36586        0.81595       0.805918
#
#     average_precision_train  average_precision_valid  fold
# 13                 0.381726                 0.372118     1

# %%
fold_1.loc[[fold_1.average_precision_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 13     13    0.356319     0.36586        0.81595       0.805918
#
#     average_precision_train  average_precision_valid  fold
# 13                 0.381726                 0.372118     1

# %%
fold_1.plot(subplots=True, figsize=(16, 8))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
fold_2 = pd.read_csv("weights/vit_base_r50_s16_384_fold2_final.csv")
fold_2
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 0       0    0.457481    0.499121       0.647612       0.742571
# 1       1    0.422669    0.399628       0.705435       0.761208
# 2       2    0.413580    0.394008       0.725978       0.774377
# 3       3    0.409747    0.403704       0.737125       0.775639
# 4       4    0.404660    0.388530       0.748112       0.789908
# 5       5    0.405101    0.382207       0.747942       0.790358
# 6       6    0.398022    0.378304       0.754450       0.793105
# 7       7    0.396169    0.379645       0.759122       0.790807
# 8       8    0.396045    0.380249       0.760935       0.786321
# 9       9    0.368479    0.370496       0.801441       0.795737
# 10     10    0.364608    0.369784       0.810981       0.797332
# 11     11    0.360526    0.369515       0.815740       0.799515
# 12     12    0.357619    0.367398       0.818442       0.798700
# 13     13    0.353524    0.372055       0.823207       0.797024
# 14     14    0.351613    0.386387       0.824670       0.798327
# 15     15    0.349767    0.370873       0.828309       0.800235
# 16     16    0.348937    0.369957       0.828603       0.800505
# 17     17    0.346594    0.369851       0.830514       0.800453
# 18     18    0.346525    0.369898       0.832433       0.800518
# 19     19    0.347930    0.369884       0.829866       0.800513
#
#     average_precision_train  average_precision_valid  fold
# 0                  0.259354                 0.321594     2
# 1                  0.287853                 0.328081     2
# 2                  0.298283                 0.342722     2
# 3                  0.306008                 0.337942     2
# 4                  0.315385                 0.352567     2
# 5                  0.312663                 0.357772     2
# 6                  0.321943                 0.351338     2
# 7                  0.318562                 0.351640     2
# 8                  0.328312                 0.355473     2
# 9                  0.360320                 0.362777     2
# 10                 0.368888                 0.366418     2
# 11                 0.374643                 0.365443     2
# 12                 0.379375                 0.369763     2
# 13                 0.384251                 0.363845     2
# 14                 0.388521                 0.363152     2
# 15                 0.388648                 0.367241     2
# 16                 0.391772                 0.367571     2
# 17                 0.390609                 0.367697     2
# 18                 0.393397                 0.367722     2
# 19                 0.391740                 0.367746     2

# %%
fold_2.loc[[fold_2.roc_auc_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 18     18    0.346525    0.369898       0.832433       0.800518
#
#     average_precision_train  average_precision_valid  fold
# 18                 0.393397                 0.367722     2

# %%
fold_2.loc[[fold_2.average_precision_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 12     12    0.357619    0.367398       0.818442         0.7987
#
#     average_precision_train  average_precision_valid  fold
# 12                 0.379375                 0.369763     2

# %%
fold_2.plot(subplots=True, figsize=(16, 8))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
fold_3 = pd.read_csv("weights/vit_base_r50_s16_384_fold3_final.csv")
fold_3
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 0       0    0.473654    0.397478       0.614097       0.758664
# 1       1    0.435082    0.405082       0.684164       0.754426
# 2       2    0.417774    0.419894       0.722184       0.771203
# 3       3    0.384383    0.370665       0.776992       0.802304
# 4       4    0.377522    0.364899       0.785575       0.809032
# 5       5    0.373080    0.379702       0.795768       0.800437
# 6       6    0.368525    0.364930       0.801048       0.811279
# 7       7    0.366128    0.362520       0.803729       0.810158
# 8       8    0.362228    0.362178       0.810893       0.810622
# 9       9    0.364929    0.361824       0.803595       0.810459
# 10     10    0.361418    0.363165       0.812271       0.809109
# 11     11    0.361551    0.361991       0.811017       0.810682
#
#     average_precision_train  average_precision_valid  fold
# 0                  0.238968                 0.330697     3
# 1                  0.274322                 0.327759     3
# 2                  0.295714                 0.335827     3
# 3                  0.340372                 0.358934     3
# 4                  0.348521                 0.363845     3
# 5                  0.356026                 0.360177     3
# 6                  0.362651                 0.366037     3
# 7                  0.367334                 0.365882     3
# 8                  0.372347                 0.366268     3
# 9                  0.368471                 0.366421     3
# 10                 0.377676                 0.365755     3
# 11                 0.377046                 0.366730     3

# %%
fold_3.loc[[fold_3.roc_auc_valid.idxmax()]]
# Out:
#    epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 6      6    0.368525     0.36493       0.801048       0.811279
#
#    average_precision_train  average_precision_valid  fold
# 6                 0.362651                 0.366037     3

# %%
fold_3.loc[[fold_3.average_precision_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 11     11    0.361551    0.361991       0.811017       0.810682
#
#     average_precision_train  average_precision_valid  fold
# 11                 0.377046                  0.36673     3

# %%
fold_3.plot(subplots=True, figsize=(16, 8))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
fold_4 = pd.read_csv("weights/vit_base_r50_s16_384_fold4_final.csv")
fold_4
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 0       0    0.473959    0.432045       0.618087       0.716912
# 1       1    0.431856    0.425566       0.686956       0.743956
# 2       2    0.420432    0.453561       0.709965       0.757687
# 3       3    0.410895    0.443581       0.732858       0.752485
# 4       4    0.384054    0.379039       0.772700       0.788350
# 5       5    0.377253    0.376202       0.784111       0.794421
# 6       6    0.372192    0.373344       0.793167       0.797139
# 7       7    0.371039    0.373748       0.798850       0.796357
# 8       8    0.368276    0.372813       0.798613       0.800957
# 9       9    0.370257    0.371277       0.796760       0.804694
# 10     10    0.365174    0.376650       0.802724       0.804263
# 11     11    0.365557    0.370565       0.803187       0.808805
# 12     12    0.362665    0.370849       0.804721       0.807191
# 13     13    0.361777    0.365913       0.807990       0.810806
# 14     14    0.359052    0.366609       0.812950       0.810158
# 15     15    0.355578    0.371967       0.816336       0.807108
# 16     16    0.347863    0.368050       0.827467       0.810373
# 17     17    0.350855    0.366126       0.825770       0.811769
# 18     18    0.348856    0.366235       0.823943       0.811720
# 19     19    0.350397    0.366162       0.824380       0.811813
#
#     average_precision_train  average_precision_valid  fold
# 0                  0.241986                 0.299342     4
# 1                  0.279258                 0.317074     4
# 2                  0.292105                 0.325838     4
# 3                  0.302786                 0.328493     4
# 4                  0.333141                 0.353642     4
# 5                  0.343523                 0.359007     4
# 6                  0.347619                 0.359405     4
# 7                  0.351443                 0.364835     4
# 8                  0.351732                 0.369009     4
# 9                  0.352488                 0.370981     4
# 10                 0.356999                 0.368528     4
# 11                 0.358534                 0.374355     4
# 12                 0.362112                 0.372051     4
# 13                 0.363979                 0.377367     4
# 14                 0.370266                 0.373040     4
# 15                 0.374629                 0.374168     4
# 16                 0.387718                 0.376450     4
# 17                 0.386265                 0.378179     4
# 18                 0.386583                 0.378248     4
# 19                 0.383533                 0.378370     4

# %%
fold_4.loc[[fold_4.roc_auc_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 19     19    0.350397    0.366162        0.82438       0.811813
#
#     average_precision_train  average_precision_valid  fold
# 19                 0.383533                  0.37837     4

# %%
fold_4.loc[[fold_4.average_precision_valid.idxmax()]]
# Out:
#     epoch  loss_train  loss_valid  roc_auc_train  roc_auc_valid  \
# 19     19    0.350397    0.366162        0.82438       0.811813
#
#     average_precision_train  average_precision_valid  fold
# 19                 0.383533                  0.37837     4

# %%
fold_4.plot(subplots=True, figsize=(16, 8))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)
