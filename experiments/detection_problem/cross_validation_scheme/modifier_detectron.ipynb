# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('detectron_prepared_data/detectron_prepared_df.csv')
df
# Out:
#                 image_id       x_min       y_min       x_max       y_max  \
# 0     000a312787f2_image  2245.91208   591.20528  3340.57370  2352.75472
# 1     000a312787f2_image   789.28836   582.43035  1815.94498  2499.73327
# 2     000c3a3f293f_image     0.00000     0.00000     1.00000     1.00000
# 3     0012ff7358bc_image   677.42216   197.97662  1545.21983  1197.75876
# 4     0012ff7358bc_image  1792.69064   402.55250  2409.71798  1606.91050
# ...                  ...         ...         ...         ...         ...
# 9583  ffd9b6cf2961_image  2197.38566   841.07361  2513.80265  1292.71119
# 9584  ffdc682f7680_image  1005.81250  1584.67711  1668.04163  2360.51048
# 9585  ffdc682f7680_image  2729.27083   332.26044  4225.52099  2936.84378
# 9586  ffe942c8655f_image   755.52522   144.33069  1183.39442   692.09119
# 9587  ffe942c8655f_image   208.86463    91.53448   659.83210   719.58921
#
#      str_label            study_id  width  height  frac_xmin  frac_xmax  \
# ...

# %%
df['binary_class'] -= 1
df['binary_class'] = df['binary_class'].astype(bool).astype(int)
df
# Out:
#                 image_id       x_min       y_min       x_max       y_max  \
# 0     000a312787f2_image  2245.91208   591.20528  3340.57370  2352.75472
# 1     000a312787f2_image   789.28836   582.43035  1815.94498  2499.73327
# 2     000c3a3f293f_image     0.00000     0.00000     1.00000     1.00000
# 3     0012ff7358bc_image   677.42216   197.97662  1545.21983  1197.75876
# 4     0012ff7358bc_image  1792.69064   402.55250  2409.71798  1606.91050
# ...                  ...         ...         ...         ...         ...
# 9583  ffd9b6cf2961_image  2197.38566   841.07361  2513.80265  1292.71119
# 9584  ffdc682f7680_image  1005.81250  1584.67711  1668.04163  2360.51048
# 9585  ffdc682f7680_image  2729.27083   332.26044  4225.52099  2936.84378
# 9586  ffe942c8655f_image   755.52522   144.33069  1183.39442   692.09119
# 9587  ffe942c8655f_image   208.86463    91.53448   659.83210   719.58921
#
#      str_label            study_id  width  height  frac_xmin  frac_xmax  \
# ...

# %%
df.to_csv('modified_detectron_data/detectron_prepared_df.csv', index=False)

# %%
df = pd.read_csv('modified_detectron_data/detectron_prepared_df.csv')
df
# Out:
#                 image_id       x_min       y_min       x_max       y_max  \
# 0     000a312787f2_image  2245.91208   591.20528  3340.57370  2352.75472
# 1     000a312787f2_image   789.28836   582.43035  1815.94498  2499.73327
# 2     000c3a3f293f_image     0.00000     0.00000     1.00000     1.00000
# 3     0012ff7358bc_image   677.42216   197.97662  1545.21983  1197.75876
# 4     0012ff7358bc_image  1792.69064   402.55250  2409.71798  1606.91050
# ...                  ...         ...         ...         ...         ...
# 9583  ffd9b6cf2961_image  2197.38566   841.07361  2513.80265  1292.71119
# 9584  ffdc682f7680_image  1005.81250  1584.67711  1668.04163  2360.51048
# 9585  ffdc682f7680_image  2729.27083   332.26044  4225.52099  2936.84378
# 9586  ffe942c8655f_image   755.52522   144.33069  1183.39442   692.09119
# 9587  ffe942c8655f_image   208.86463    91.53448   659.83210   719.58921
#
#      str_label            study_id  width  height  frac_xmin  frac_xmax  \
# ...
